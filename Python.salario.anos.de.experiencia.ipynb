# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Create a scatter plot with a linear regression line
plt.figure(figsize=(10, 6))
sns.regplot(x='Experience Years', y='Salary', data=df)
plt.title('Scatter Plot of Experience Years vs. Salary with Regression Line')
plt.xlabel('Experience Years')
plt.ylabel('Salary')
plt.grid(True)
plt.show()

# %%
import pandas as pd

url = 'https://raw.githubusercontent.com/ybifoundation/Dataset/main/Salary%20Data.csv'
df = pd.read_csv(url)

display(df.head())
# Out:
#    Experience Years  Salary
# 0               1.1   39343
# 1               1.2   42774
# 2               1.3   46205
# 3               1.5   37731
# 4               2.0   43525
